# %%
import pandas as pd
from ydata_profiling import ProfileReport
import numpy as np
from rdkit.Chem import Descriptors, Lipinski
from rdkit import Chem

# %%
DB = pd.read_csv('./Data_BindingDB/effective_raw_data_clean_for_calculation.csv')
DB
# Out:
#      BindingDB MonomerID                                      Ligand SMILES  \
# 0               50008602     Cc1ccc(CC(CS)C(=O)Nc2ccc(cc2)S([O-])(=O)=O)cc1
# 1               50025914         ON(CC(Cc1ccccc1)C(=O)NCC(=O)NCc1ccccc1)C=O
# 2               50050158  C[C@H](NC(=O)[C@H](S)Cc1ccccc1)C(=O)N1CCCC1C(O)=O
# 3               50285328  OP(O)(=O)CN[C@@H](Cc1ccc(cc1)-c1ccccc1)C(=O)Nc...
# 4               50025913                   ON(C=O)C(Cc1ccccc1)C(=O)NCC(O)=O
# ..                   ...                                                ...
# 306             50503908  CCCCc1nc(Cl)c(CNC(=O)C(CS)C(C)C)n1Cc1ccc(cc1)-...
# 307             50089197                       CCCCC(CC(=O)NO)S(=O)c1ccccc1
# 308             50287131  CC(C)C(NC(=O)C(Cc1ccccc1)CP(O)(=O)[C@H](Cc1ccc...
# 309             50190751           CCCC(CC1(CCCC1)c1nnc(Cc2ccccc2)o1)C(O)=O
# 310             50503888  CCCCc1nc(Cl)c(CNC(=O)C(CS)CC(C)C)n1Cc1ccc(cc1)...
#
#      IC50 (nM)
# 0     8.958607
# 1     8.920819
# ...

# %%
report_DB = ProfileReport(DB)
report_DB
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v4.8.3&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-06-01 03:33:19.672688&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
Chembl = pd.read_csv('./Data/effective_raw_data_clean.csv')
Chembl['Standard Value'] = Chembl['Standard Value'].apply(lambda x: -np.log10(x * 10**(-9)))
Chembl
# Out:
#     Molecule ChEMBL ID                                             Smiles  \
# 0         CHEMBL276690  O=P(O)(O)C(Cc1cccc2c1OCO2)N[C@@H](Cc1ccc(-c2cc...
# 1         CHEMBL431691  CC(O)C(NC(=O)C(Cc1ccccc1)CP(=O)(O)[C@H](Cc1ccc...
# 2         CHEMBL212001                 CCc1nnc(NC(=O)C2(CCC(=O)O)CCCC2)s1
# 3          CHEMBL27842  NC(=O)CC(NC(=O)C(Cc1ccccc1)CP(=O)(O)[C@H](Cc1c...
# 4         CHEMBL273898             CC(C)CC(NC(=O)C(CS)C(C)c1ccccc1)C(=O)O
# ..                 ...                                                ...
# 463      CHEMBL3221954        COC(=O)[C@H](CC(=O)N[C@@H](CO)C(=O)O)CC(C)C
# 464      CHEMBL4434901  O=C(O)CCC(=O)N[C@@H](CC(=O)O)Cc1ccc(-c2ccccc2F...
# 465      CHEMBL4550194  CC(=O)Nc1cccc(-c2ccc(C[C@H](CC(=O)O)NC(=O)CCC(...
# 466        CHEMBL50582  C[C@H](NC(=O)[C@@H](CS)Cc1ccccc1)C(=O)N1c2cccc...
# 467        CHEMBL49920  C[C@H](NC(=O)[C@@H](CS)Cc1ccccc1)C(=O)N1Cc2ccc...
#
#      Standard Value  AlogP  Molecular Weight
# ...

# %%
report_chem = ProfileReport(Chembl)
report_chem
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v4.8.3&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-06-01 03:36:38.355647&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
smiles_db = DB['Ligand SMILES']
smiles_chembl = Chembl['Smiles']
for i in smiles_db:
    for j in smiles_chembl:
        if i == j:
            print('True')
