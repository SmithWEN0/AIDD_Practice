# %%
import pandas as pd
import numpy as np
from ydata_profiling import ProfileReport

# %%
raw_data = pd.read_csv('./Data/raw_data_Neprilysin.csv', sep = ';', engine='python')
raw_data
# Out:
#     Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 0         CHEMBL276690           NaN                 NaN            493.46
# 1         CHEMBL431691           NaN                 NaN            582.59
# 2         CHEMBL212001           NaN                 NaN            297.38
# 3          CHEMBL27842           NaN                 NaN            595.59
# 4         CHEMBL273898           NaN                 NaN            323.46
# ..                 ...           ...                 ...               ...
# 525       CHEMBL299639           NaN                 NaN            398.48
# 526        CHEMBL50582           NaN                 NaN            412.51
# 527        CHEMBL51576           NaN                 NaN            398.48
# 528       CHEMBL287896           NaN                 NaN            350.44
# 529        CHEMBL49920           NaN                 NaN            426.54
#
#      #RO5 Violations  AlogP                        Compound Key  \
# ...

# %%
raw_data.columns
# Out:
# Index(['Molecule ChEMBL ID', 'Molecule Name', 'Molecule Max Phase',
#        'Molecular Weight', '#RO5 Violations', 'AlogP', 'Compound Key',
#        'Smiles', 'Standard Type', 'Standard Relation', 'Standard Value',
#        'Standard Units', 'pChEMBL Value', 'Data Validity Comment', 'Comment',
#        'Uo Units', 'Ligand Efficiency BEI', 'Ligand Efficiency LE',
#        'Ligand Efficiency LLE', 'Ligand Efficiency SEI', 'Potential Duplicate',
#        'Assay ChEMBL ID', 'Assay Description', 'Assay Type', 'BAO Format ID',
#        'BAO Label', 'Assay Organism', 'Assay Tissue ChEMBL ID',
#        'Assay Tissue Name', 'Assay Cell Type', 'Assay Subcellular Fraction',
#        'Assay Parameters', 'Assay Variant Accession', 'Assay Variant Mutation',
#        'Target ChEMBL ID', 'Target Name', 'Target Organism', 'Target Type',
#        'Document ChEMBL ID', 'Source ID', 'Source Description',
#        'Document Journal', 'Document Year', 'Cell ChEMBL ID', 'Properties',
# ...

# %%
effective_raw_data = raw_data[['Molecule ChEMBL ID', 'Smiles', 'Standard Value', 'AlogP', 'Molecular Weight']]
effective_raw_data
# Out:
#     Molecule ChEMBL ID                                             Smiles  \
# 0         CHEMBL276690  O=P(O)(O)C(Cc1cccc2c1OCO2)N[C@@H](Cc1ccc(-c2cc...
# 1         CHEMBL431691  CC(O)C(NC(=O)C(Cc1ccccc1)CP(=O)(O)[C@H](Cc1ccc...
# 2         CHEMBL212001                 CCc1nnc(NC(=O)C2(CCC(=O)O)CCCC2)s1
# 3          CHEMBL27842  NC(=O)CC(NC(=O)C(Cc1ccccc1)CP(=O)(O)[C@H](Cc1c...
# 4         CHEMBL273898             CC(C)CC(NC(=O)C(CS)C(C)c1ccccc1)C(=O)O
# ..                 ...                                                ...
# 525       CHEMBL299639  O=C(O)CN1C(=O)[C@@H](NC(=O)[C@@H](S)Cc2ccccc2)...
# 526        CHEMBL50582  C[C@H](NC(=O)[C@@H](CS)Cc1ccccc1)C(=O)N1c2cccc...
# 527        CHEMBL51576  O=C(O)CN1Cc2ccccc2C[C@H](NC(=O)[C@@H](S)Cc2ccc...
# 528       CHEMBL287896  C[C@H](NC(=O)[C@@H](S)Cc1ccccc1)C(=O)N1CCC[C@H...
# 529        CHEMBL49920  C[C@H](NC(=O)[C@@H](CS)Cc1ccccc1)C(=O)N1Cc2ccc...
#
#      Standard Value  AlogP  Molecular Weight
# ...

# %%
report = ProfileReport(effective_raw_data)
report
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v4.8.3&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-05-31 13:51:55.827547&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
# pd.set_option('display.max_rows', None)
effective_raw_data = raw_data[['Molecule ChEMBL ID', 'Smiles', 'Standard Value', 'AlogP', 'Molecular Weight']]
effective_raw_data
# Out:
#     Molecule ChEMBL ID                                             Smiles  \
# 0         CHEMBL276690  O=P(O)(O)C(Cc1cccc2c1OCO2)N[C@@H](Cc1ccc(-c2cc...
# 1         CHEMBL431691  CC(O)C(NC(=O)C(Cc1ccccc1)CP(=O)(O)[C@H](Cc1ccc...
# 2         CHEMBL212001                 CCc1nnc(NC(=O)C2(CCC(=O)O)CCCC2)s1
# 3          CHEMBL27842  NC(=O)CC(NC(=O)C(Cc1ccccc1)CP(=O)(O)[C@H](Cc1c...
# 4         CHEMBL273898             CC(C)CC(NC(=O)C(CS)C(C)c1ccccc1)C(=O)O
# ..                 ...                                                ...
# 525       CHEMBL299639  O=C(O)CN1C(=O)[C@@H](NC(=O)[C@@H](S)Cc2ccccc2)...
# 526        CHEMBL50582  C[C@H](NC(=O)[C@@H](CS)Cc1ccccc1)C(=O)N1c2cccc...
# 527        CHEMBL51576  O=C(O)CN1Cc2ccccc2C[C@H](NC(=O)[C@@H](S)Cc2ccc...
# 528       CHEMBL287896  C[C@H](NC(=O)[C@@H](S)Cc1ccccc1)C(=O)N1CCC[C@H...
# 529        CHEMBL49920  C[C@H](NC(=O)[C@@H](CS)Cc1ccccc1)C(=O)N1Cc2ccc...
#
#      Standard Value  AlogP  Molecular Weight
# ...

# %%
# effective_raw_data.to_csv('./Data/effective_raw_data.csv', index=None)
